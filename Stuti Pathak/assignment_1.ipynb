# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris[['petal_length','petal_width']]
iris
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
x = iris['petal_length']
y = iris['petal_width']

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('petal length')
plt.ylabel('petal width')
# Out:
# Text(0, 0.5, 'petal width')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.6, random_state = 25)
x_train
# Out:
# 71     4.0
# 97     4.3
# 51     4.5
# 130    6.1
# 87     4.4
# 37     1.4
# 100    6.0
# 14     1.2
# 17     1.4
# 74     4.3
# 83     5.1
# 137    5.5
# 146    5.0
# 90     4.4
# 43     1.6
# 111    5.3
# 11     1.6
# 22     1.0
# 73     4.7
# 57     3.3
# 5      1.7
# 2      1.3
# 38     1.3
# 112    5.5
# 107    6.3
# 104    5.8
# 101    5.1
# 30     1.6
# 98     3.0
# 141    5.1
# 92     4.0
# 18     1.7
# 49     1.4
# 91     4.6
# 86     4.7
# 134    5.6
# 106    4.5
# 147    5.2
# 60     3.5
# 36     1.3
# 50     4.7
# 109    6.1
# 47     1.4
# 48     1.5
# 1      1.4
# 131    6.4
# 45     1.4
# 84     4.5
# 140    5.6
# 88     4.1
# 3      1.5
# 129    5.8
# 89     4.0
# 149    5.1
# 136    5.6
# 118    6.9
# 61     4.2
# 143    5.9
# 62     4.0
# 132    5.6
# Name: petal_length, dtype: float64

# %%
import numpy as np
x_train = np.array(x_train).reshape(-1,1)
x_train
# Out:
# array([[4. ],
#        [4.3],
#        [4.5],
#        [6.1],
#        [4.4],
#        [1.4],
#        [6. ],
#        [1.2],
#        [1.4],
#        [4.3],
#        [5.1],
#        [5.5],
#        [5. ],
#        [4.4],
#        [1.6],
#        [5.3],
#        [1.6],
#        [1. ],
#        [4.7],
#        [3.3],
#        [1.7],
#        [1.3],
#        [1.3],
#        [5.5],
#        [6.3],
#        [5.8],
#        [5.1],
#        [1.6],
#        [3. ],
#        [5.1],
#        [4. ],
#        [1.7],
#        [1.4],
#        [4.6],
#        [4.7],
#        [5.6],
#        [4.5],
#        [5.2],
#        [3.5],
#        [1.3],
#        [4.7],
#        [6.1],
#        [1.4],
#        [1.5],
#        [1.4],
#        [6.4],
#        [1.4],
#        [4.5],
#        [5.6],
#        [4.1],
#        [1.5],
#        [5.8],
#        [4. ],
#        [5.1],
#        [5.6],
#        [6.9],
#        [4.2],
#        [5.9],
#        [4. ],
#        [5.6]])

# %%
x_test = np.array(x_test).reshape(-1,1)
x_test
# Out:
# array([[1.4],
#        [4.9],
#        [4.8],
#        [4.5],
#        [5.6],
#        [4.4],
#        [4.9],
#        [1.3],
#        [3.7],
#        [3.3],
#        [1.5],
#        [1.5],
#        [1.6],
#        [5.1],
#        [1.4],
#        [4.6],
#        [6. ],
#        [5.4],
#        [3.6],
#        [4.2],
#        [3.5],
#        [4.1],
#        [4.5],
#        [1.7],
#        [1.5],
#        [6.7],
#        [3.9],
#        [6.7],
#        [5.7],
#        [1.3],
#        [4.6],
#        [5. ],
#        [6.1],
#        [1.4],
#        [5.3],
#        [4.9],
#        [4.5],
#        [1.3],
#        [1.7],
#        [1.2],
#        [1.3],
#        [1.4],
#        [1.4],
#        [1.6],
#        [4.8],
#        [1.5],
#        [1.4],
#        [4.5],
#        [1.5],
#        [4.9],
#        [5.9],
#        [1.5],
#        [1.4],
#        [5.6],
#        [3.9],
#        [5.1],
#        [5.2],
#        [4.5],
#        [5.7],
#        [4.2],
#        [4.8],
#        [5.8],
#        [3.8],
#        [1.5],
#        [5. ],
#        [4.7],
#        [5.1],
#        [1.5],
#        [3.9],
#        [5. ],
#        [1.5],
#        [1.9],
#        [5.7],
#        [4.7],
#        [4.4],
#        [1.9],
#        [6.6],
#        [4.1],
#        [5.1],
#        [4.2],
#        [5.5],
#        [1.1],
#        [1.6],
#        [4. ],
#        [1.6],
#        [1.5],
#        [4.8],
#        [4.9],
#        [1.5],
#        [5.4]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# -0.3437821525072813

# %%
m = lr.coef_
m
# Out:
# array([0.40951679])

# %%
y_pred_train = m*(x_train) + c
y_pred_train.flatten()
# Out:
# array([1.29428501, 1.41714005, 1.49904341, 2.15427027, 1.45809173,
#        0.22954136, 2.11331859, 0.147638  , 0.22954136, 1.41714005,
#        1.74475348, 1.9085602 , 1.7038018 , 1.45809173, 0.31144471,
#        1.82665684, 0.31144471, 0.06573464, 1.58094677, 1.00762326,
#        0.35239639, 0.18858968, 0.18858968, 1.9085602 , 2.23617363,
#        2.03141524, 1.74475348, 0.31144471, 0.88476822, 1.74475348,
#        1.29428501, 0.35239639, 0.22954136, 1.53999509, 1.58094677,
#        1.94951188, 1.49904341, 1.78570516, 1.08952662, 0.18858968,
#        1.58094677, 2.15427027, 0.22954136, 0.27049303, 0.22954136,
#        2.27712531, 0.22954136, 1.49904341, 1.94951188, 1.33523669,
#        0.27049303, 2.03141524, 1.29428501, 1.74475348, 1.94951188,
#        2.48188371, 1.37618837, 2.07236692, 1.29428501, 1.94951188])

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_train,y_pred_train,color = 'green')
plt.xlabel("petal length")
plt.ylabel("petal width")
# Out:
# Text(0, 0.5, 'petal width')

# %%
y_pred_test=m*(x_test)+c
y_pred_test.flatten()
# Out:
# array([0.22954136, 1.66285012, 1.62189845, 1.49904341, 1.94951188,
#        1.45809173, 1.66285012, 0.18858968, 1.17142998, 1.00762326,
#        0.27049303, 0.27049303, 0.31144471, 1.74475348, 0.22954136,
#        1.53999509, 2.11331859, 1.86760852, 1.1304783 , 1.37618837,
#        1.08952662, 1.33523669, 1.49904341, 0.35239639, 0.27049303,
#        2.39998035, 1.25333333, 2.39998035, 1.99046356, 0.18858968,
#        1.53999509, 1.7038018 , 2.15427027, 0.22954136, 1.82665684,
#        1.66285012, 1.49904341, 0.18858968, 0.35239639, 0.147638  ,
#        0.18858968, 0.22954136, 0.22954136, 0.31144471, 1.62189845,
#        0.27049303, 0.22954136, 1.49904341, 0.27049303, 1.66285012,
#        2.07236692, 0.27049303, 0.22954136, 1.94951188, 1.25333333,
#        1.74475348, 1.78570516, 1.49904341, 1.99046356, 1.37618837,
#        1.62189845, 2.03141524, 1.21238165, 0.27049303, 1.7038018 ,
#        1.58094677, 1.74475348, 0.27049303, 1.25333333, 1.7038018 ,
#        0.27049303, 0.43429975, 1.99046356, 1.58094677, 1.45809173,
#        0.43429975, 2.35902867, 1.33523669, 1.74475348, 1.37618837,
#        1.9085602 , 0.10668632, 0.31144471, 1.29428501, 0.31144471,
#        0.27049303, 1.62189845, 1.66285012, 0.27049303, 1.86760852])

# %%
plt.scatter(x_test,y_test)
plt.scatter(x_test,y_pred_test,color='green')
plt.xlabel("petal length")
plt.ylabel("petal width")
# Out:
# Text(0, 0.5, 'petal width')

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_test,y_pred_test,color='green')
plt.xlabel("petal length")
plt.ylabel("petal width")
# Out:
# Text(0, 0.5, 'petal width')
